# %% [markdown]
# <a href="https://colab.research.google.com/github/mauriciolalvarado-dot/CURSO-PYTHON-CUCSH/blob/main/Copia_de_Proyecto_3_Proceso_de_admision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Mauricio López Alvarado

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
# Ruta al archivo en su Google Drive
ruta_archivo = "/content/drive/MyDrive/Colab Data/applicant_list_7.txt"
nombre_columnas = ['nombre', 'apellido', 'EPH', 'ECH', 'EMA', 'ECS', 'ESP', 'OP1', 'OP2', 'OP3']
df = pd.read_csv(ruta_archivo, sep=' ', names=nombre_columnas)
display(df.head())
# Out:
#      nombre   apellido  EPH  ECH  EMA  ECS  ESP          OP1          OP2  \
# 0   Jermine    Brunton   84   81   73   92   48      Physics  Engineering
# 1     Justo     Mirfin   71   77   61   60   41  Engineering      Biotech
# 2      Uzma  Naysmythe   60   94   75   71   80    Chemistry  Engineering
# 3     Koury      Wingo   71   81   81   83   59  Engineering      Biotech
# 4  Kentrell  Hillhouse   40   69   42   58   20  Mathematics  Engineering
#
#            OP3
# 0  Mathematics
# 1    Chemistry
# 2  Mathematics
# 3  Mathematics
# 4      Biotech
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['EPH'].plot(kind='hist', bins=20, title='EPH')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['ECH'].plot(kind='hist', bins=20, title='ECH')
# ...
