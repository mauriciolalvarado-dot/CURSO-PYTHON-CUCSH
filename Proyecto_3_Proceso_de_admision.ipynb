# %% [markdown]
# <a href="https://colab.research.google.com/github/mauriciolalvarado-dot/CURSO-PYTHON-CUCSH/blob/main/Proyecto_3_Proceso_de_admision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Mauricio López Alvarado**
# Curso CUCSH-PROINNOVA
#
# Unidad 3. Proyecto 3.
#
# **Selección de aspirantes en proceso de admisión**
#
# Octubre de 2025

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
# Ruta al archivo en su Google Drive
ruta_archivo = "/content/drive/MyDrive/Colab Data/applicant_list_7.txt"
nombre_columnas = ['nombre', 'apellido', 'EPH', 'ECH', 'EMA', 'ECS', 'ESP', 'OP1', 'OP2', 'OP3']
df = pd.read_csv(ruta_archivo, sep=' ', names=nombre_columnas)
display(df.head())
# Out:
#      nombre   apellido  EPH  ECH  EMA  ECS  ESP          OP1          OP2  \
# 0   Jermine    Brunton   84   81   73   92   48      Physics  Engineering
# 1     Justo     Mirfin   71   77   61   60   41  Engineering      Biotech
# 2      Uzma  Naysmythe   60   94   75   71   80    Chemistry  Engineering
# 3     Koury      Wingo   71   81   81   83   59  Engineering      Biotech
# 4  Kentrell  Hillhouse   40   69   42   58   20  Mathematics  Engineering
#
#            OP3
# 0  Mathematics
# 1    Chemistry
# 2  Mathematics
# 3  Mathematics
# 4      Biotech

# %%
print(df.shape)
df.info()
# Out:
# (98, 10)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98 entries, 0 to 97
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   nombre    98 non-null     object
#  1   apellido  98 non-null     object
#  2   EPH       98 non-null     int64
#  3   ECH       98 non-null     int64
#  4   EMA       98 non-null     int64
#  5   ECS       98 non-null     int64
#  6   ESP       98 non-null     int64
#  7   OP1       98 non-null     object
#  8   OP2       98 non-null     object
#  9   OP3       98 non-null     object
# dtypes: int64(5), object(5)
# memory usage: 7.8+ KB

# %%
display(df)
# Out:
#        nombre   apellido  EPH  ECH  EMA  ECS  ESP          OP1          OP2  \
# 0     Jermine    Brunton   84   81   73   92   48      Physics  Engineering
# 1       Justo     Mirfin   71   77   61   60   41  Engineering      Biotech
# 2        Uzma  Naysmythe   60   94   75   71   80    Chemistry  Engineering
# 3       Koury      Wingo   71   81   81   83   59  Engineering      Biotech
# 4    Kentrell  Hillhouse   40   69   42   58   20  Mathematics  Engineering
# ..        ...        ...  ...  ...  ...  ...  ...          ...          ...
# 93     Tamkia       Fish   81   71   73   86   78      Physics  Engineering
# 94      Deniz  Blanchard   71   77   61   60   61  Engineering      Biotech
# 95       Mira      Riley   60   94   75   71   80  Engineering      Biotech
# 96      Loura    Macansh   71   81   81   93   79  Engineering      Physics
# 97  Nastassja   Trustram   60   49   82   68   70  Mathematics  Engineering
#
#             OP3
# 0   Mathematics
# 1     Chemistry
# 2   Mathematics
# 3   Mathematics
# 4       Biotech
# ..          ...
# 93  Mathematics
# 94    Chemistry
# 95  Mathematics
# 96  Mathematics
# 97      Physics
#
# [98 rows x 10 columns]

# %%
# definicion de una funcion para estimar puntaje de admision

# %%
import pandas as pd
def calcular_puntaje_admision(linea, opcion):
  departmento = linea[opcion]

  if departmento == 'Physics':
    puntajes = [linea['EPH'], linea['EMA'], linea['ESP']]
  elif departmento == 'Mathematics':
    puntajes = [linea['EMA'], linea['ECS'], linea['ESP']]
  elif departmento == 'Engineering':
    puntajes = [linea['EMA'], linea['ECS'], linea['EPH'], linea['ESP']]
  elif departmento == 'Chemistry':
    puntajes = [linea['ECH'], linea['EPH'], linea['ESP']]
  elif departmento == 'Biotech':
    puntajes = [linea['EMA'], linea['ECS'], linea['ECH'], linea['ESP']]
  else:
    return None  # Para caso cuando departamento no esta en la lista

  return round(sum(puntajes) / len(puntajes), 2)

# %%
import pandas as pd
# Ruta al archivo en su Google Drive
ruta_archivo = "/content/drive/MyDrive/Colab Data/applicant_list_7.txt"
nombre_columnas = ['nombre', 'apellido', 'EPH', 'ECH', 'EMA', 'ECS', 'ESP', 'OP1', 'OP2', 'OP3']
df = pd.read_csv(ruta_archivo, sep=' ', names=nombre_columnas)
display(df.head())
# Out:
#      nombre   apellido  EPH  ECH  EMA  ECS  ESP          OP1          OP2  \
# 0   Jermine    Brunton   84   81   73   92   48      Physics  Engineering
# 1     Justo     Mirfin   71   77   61   60   41  Engineering      Biotech
# 2      Uzma  Naysmythe   60   94   75   71   80    Chemistry  Engineering
# 3     Koury      Wingo   71   81   81   83   59  Engineering      Biotech
# 4  Kentrell  Hillhouse   40   69   42   58   20  Mathematics  Engineering
#
#            OP3
# 0  Mathematics
# 1    Chemistry
# 2  Mathematics
# 3  Mathematics
# 4      Biotech

# %%
# Apply the function to create new score columns
df['OP1_score'] = df.apply(lambda row: calcular_puntaje_admision(row, 'OP1'), axis=1)
df['OP2_score'] = df.apply(lambda row: calcular_puntaje_admision(row, 'OP2'), axis=1)
df['OP3_score'] = df.apply(lambda row: calcular_puntaje_admision(row, 'OP3'), axis=1)

# Add the full name column
df['nombre_completo'] = df['nombre'] + ' ' + df['apellido']

# Display the updated DataFrame with the new columns
display(df.head())
# Out:
#      nombre   apellido  EPH  ECH  EMA  ECS  ESP          OP1          OP2  \
# 0   Jermine    Brunton   84   81   73   92   48      Physics  Engineering
# 1     Justo     Mirfin   71   77   61   60   41  Engineering      Biotech
# 2      Uzma  Naysmythe   60   94   75   71   80    Chemistry  Engineering
# 3     Koury      Wingo   71   81   81   83   59  Engineering      Biotech
# 4  Kentrell  Hillhouse   40   69   42   58   20  Mathematics  Engineering
#
#            OP3  OP1_score  OP2_score  OP3_score     nombre_completo
# 0  Mathematics      68.33      74.25      71.00     Jermine Brunton
# 1    Chemistry      58.25      59.75      63.00        Justo Mirfin
# 2  Mathematics      78.00      71.50      75.33      Uzma Naysmythe
# 3  Mathematics      73.50      76.00      74.33         Koury Wingo
# 4      Biotech      40.00      40.00      47.25  Kentrell Hillhouse

# %%
while True:
  try:
    N = int(input("Introduce el número máximo de alumnos en un departamento: "))
    break
  except ValueError:
    print("Entrada inválida. Por favor, introduce un número entero.")

print(f"Límite de admisión por departamento (N): {N}")
# Out:
# Introduce el número máximo de alumnos en un departamento: 20
# Límite de admisión por departamento (N): 20

# %%
departamentos = ['Biotech', 'Chemistry', 'Engineering', 'Mathematics', 'Physics']

while True:
  departamento_seleccionado = input("Introduce el departamento para la selección (Biotech, Chemistry, Engineering, Mathematics, Physics): ")
  if departamento_seleccionado in departamentos:
    break
  else:
    print("Departamento inválido. Por favor, elige uno de la lista.")

print(f"Departamento seleccionado: {departamento_seleccionado}")
# Out:
# Introduce el departamento para la selección (Biotech, Chemistry, Engineering, Mathematics, Physics): ESP
# Departamento inválido. Por favor, elige uno de la lista.
# Introduce el departamento para la selección (Biotech, Chemistry, Engineering, Mathematics, Physics): Physics
# Departamento seleccionado: Physics

# %%
# Filtrar el DataFrame para el departamento seleccionado y la opción OP1
aspirantes_departamento = df[(df['OP1'] == departamento_seleccionado)]

# Ordenar por OP1_score en orden descendente
aspirantes_ordenados = aspirantes_departamento.sort_values(by=['OP1_score'], ascending=[False])

# Seleccionar los N aspirantes con los puntajes más altos
aspirantes_elegidos = aspirantes_ordenados.head(N)

# Crear la tabla con las columnas especificadas
tabla_aspirantes_elegidos = pd.DataFrame({
    'nombre_completo': aspirantes_elegidos['nombre_completo'],
    'departmento': aspirantes_elegidos['OP1'],
    'puntaje': aspirantes_elegidos['OP1_score'],
    'opcion': 'OP1'
})

# Presentar el contenido de la tabla
display(tabla_aspirantes_elegidos)

# Imprimir el número de aspirantes elegidos
print(f"\nNúmero de aspirantes elegidos para {departamento_seleccionado} (OP1): {len(tabla_aspirantes_elegidos)}")
# Out:
#       nombre_completo departmento  puntaje opcion
# 7   Laney Braithwaite     Physics    91.33    OP1
# 19         Blia Sagar     Physics    88.00    OP1
# 71       Darrah Smyth     Physics    84.33    OP1
# 6        Sang Muldoon     Physics    81.00    OP1
# 30      Jathan Birley     Physics    81.00    OP1
# 18  Cornellius Turney     Physics    81.00    OP1
# 42    Martha Hatchard     Physics    81.00    OP1
# 33    Dashanna Herron     Physics    80.67    OP1
# 66      Giovanna Keel     Physics    79.67    OP1
# 12      Jaemi Hallets     Physics    77.33    OP1
# 93        Tamkia Fish     Physics    77.33    OP1
# 36     Derick Whatley     Physics    77.33    OP1
# 84     Jermain Stobbs     Physics    77.33    OP1
# 60  Fatemah Desavigny     Physics    77.33    OP1
# 54  Cressie Gillespie     Physics    75.33    OP1
# 90        Tyrone Fern     Physics    74.33    OP1
# 26    Madiha Milligan     Physics    73.00    OP1
# 0     Jermine Brunton     Physics    68.33    OP1
# 24      Ammon Janssen     Physics    68.33    OP1
# 48     Marquita Mcrae     Physics    68.33    OP1
# Número de aspirantes elegidos para Physics (OP1): 20
